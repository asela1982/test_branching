# %%
import requests
from config import api_key
import json
from pprint import pprint

# %%
base_url = "https://api.meetup.com/find/groups"
params = {"key": api_key,
          "zip":78727,
          "photo-host": "Public",
          "order":"most_active",
          "sign":True,          
          }
url = requests.get(base_url,params=params)
data_set = url.json()
pprint(data_set)
# Out:
# [{'category': {'id': 31,
#                'name': 'Socializing',
#                'shortname': 'socializing',
#                'sort_name': 'Socializing'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1262532520000,
#   'description': '<p><strong><em>Mission Statement: &nbsp;Our intention is to '
#                  'build an active, harmonious community of interesting people '
#                  'born near the Baby Boomer years (between 1946 and 1964) by '
#                  'offering an abundance of diverse activities that allow our '
#                  'members to come together to have fun, while nurturing our '
#                  'minds, bodies, and spirits. &nbsp;Our desire is that this '
#                  'investment of time and energy will make it easier for us to '
#                  'open our hearts to&nbsp;forming&nbsp;new connections that '
#                  'lead to lasting and meaningful '
#                  'friendships.</em></strong></p>\n'
#                  '<p><strong><em>Code of Conduct:</em></strong> <em>When '
#                  'participating in any event sanctioned as a Boomertime '
#                  'meetup, all Boomertime members shall represent themselves in '
#                  'concert with the stated mission and spirit of our community. '
#                  'Each member shall be expected to demonstrate courteous and '
#                  'cordial behavior in action and in speech at all times and to '
#                  'be accepting, respectful, and inclusive of all members, '
#                  'whether engaged in online dialogue with other members of '
#                  'Boomertime or at any and all venues at which a Boomertime '
#                  'meetup is held.</em> <em>Event Hosts shall continuously '
#                  'endeavor to create and maintain, in addition to general '
#                  'policy expectations, a welcoming, harmonious, safe, and '
#                  'otherwise supportive environment at their events, so that '
#                  'every member feels comfortable and able to become further '
#                  'integrated into the Boomertime community</em></p>\n'
#                  '<p><span><b>NOTICE OF ASSUMED RISK: '
#                  '&nbsp;</b></span><span>Meetup, Inc. and IT’S BOOMERTIME do '
#                  'NOT maintain health, auto, home, life or other insurance '
#                  'policies applicable to members of IT’s BOOMERTIME. This is a '
#                  'notice to you that risks associated with your participation '
#                  'in IT’S BOOMERTIME events, and participation of your guests '
#                  'in IT’S BOOMERTIME events, are solely your responsibility. '
#                  'Attendance at an IT’S BOOMERTIME event is your '
#                  'acknowledgement that you assume all risk and that you '
#                  'release IT’S BOOMERTIME and members of IT’S BOOMERTIME from '
#                  'any and all liability for personal injury, property damage, '
#                  'or death.</span></p>\n'
#                  '<blockquote> \n'
#                  ' <span><span>IT’S BOOMERTIME urges members to obtain '
#                  'insurance BEFORE participating in IT’S BOOMERTIME '
#                  'events.</span></span> \n'
#                  '</blockquote>\n'
#                  '<p><b>PARTICIPATION OPPORTUNITIES: </b> <br>For anyone who '
#                  'may be so inclined, there are always opportunities to be an '
#                  'Event Host or participate with the Admin Team and help '
#                  'shepherd the continued success of this group.</p>\n'
#                  '<p><strong><em> <br> </em></strong></p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/d/8/b/1/highres_464395473.jpeg',
#                   'id': 464395473,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/d/8/b/1/600_464395473.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/d/8/b/1/thumb_464395473.jpeg',
#                   'type': 'event'},
#   'id': 1576378,
#   'join_mode': 'approval',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/7/b/d/5/highres_466351701.jpeg',
#                 'id': 466351701,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/7/b/d/5/600_466351701.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/7/b/d/5/thumb_466351701.jpeg',
#                 'type': 'event'},
#   'lat': 30.26,
#   'link': 'https://www.meetup.com/boomertime/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.87,
#   'members': 3744,
#   'meta_category': {'category_ids': [31],
#                     'id': 272,
#                     'name': 'Social',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/highres_450131947.jpeg',
#                               'id': 450131947,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/600_450131947.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/thumb_450131947.jpeg',
#                               'type': 'event'},
#                     'shortname': 'social',
#                     'sort_name': 'Social'},
#   'name': "It's Boomertime!",
#   'next_event': {'id': '245309872',
#                  'name': 'Barton Creek Walk',
#                  'time': 1511618400000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 3},
#   'organizer': {'bio': '',
#                 'id': 11241436,
#                 'name': 'jeffrey solomon',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/d/c/4/0/highres_258236384.jpeg',
#                           'id': 258236384,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/d/c/4/0/member_258236384.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/c/4/0/thumb_258236384.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'boomertime',
#   'visibility': 'public',
#   'who': 'Boomers'},
#  {'category': {'id': 23,
#                'name': 'Outdoors & Adventure',
#                'shortname': 'outdoors-adventure',
#                'sort_name': 'Outdoors & Adventure'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1264563358000,
#   'description': '<p><a href="http://texas2.sierraclub.org/austin/">Austin '
#                  'Sierra Club</a> (local branch of the Sierra Club) holds '
#                  'outings for outdoor activities: hiking, camping, biking, '
#                  'backpacking, kayaking, community service projects, and more. '
#                  'These include local one-day events to greenbelts and natural '
#                  'areas, weekend trips to state parks, as well as weeklong '
#                  'trips to national parks.</p>\n'
#                  '<p>All participants must sign our <a '
#                  'href="http://files.meetup.com/1589422/SignInWaiver.pdf">Sign-In '
#                  'Sheet and Liability Waiver</a>&nbsp;before joining one of '
#                  'our outings. &nbsp;You are strongly urged to add your cell '
#                  'phone and emergency contact numbers on the sheet, for your '
#                  'safety. &nbsp;More information is needed for overnight '
#                  'trips.</p>\n'
#                  "<p>Although it's not necessary to participate in our events, "
#                  'we encourage you to<a '
#                  'href="http://sierraclub.org/texas/austin"> join the Sierra '
#                  'Club</a><a '
#                  'href="https://texas2.sierraclub.org/austin/content/join"></a> '
#                  '(in addition to the Meetup group), and support our efforts '
#                  'to protect the environment. &nbsp;</p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/a/1/8/c/highres_12821356.jpeg',
#                   'id': 12821356,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/a/1/8/c/600_12821356.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/a/1/8/c/thumb_12821356.jpeg',
#                   'type': 'event'},
#   'id': 1589422,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/a/b/6/7/highres_451843879.jpeg',
#                 'id': 451843879,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/a/b/6/7/600_451843879.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/a/b/6/7/thumb_451843879.jpeg',
#                 'type': 'event'},
#   'lat': 30.27,
#   'link': 'https://www.meetup.com/Austin-Sierra-Club-Outings/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.74,
#   'members': 12282,
#   'meta_category': {'category_ids': [3, 23],
#                     'id': 242,
#                     'name': 'Outdoors & Adventure',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/highres_450131943.jpeg',
#                               'id': 450131943,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/600_450131943.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/thumb_450131943.jpeg',
#                               'type': 'event'},
#                     'shortname': 'outdoors-adventure',
#                     'sort_name': 'Outdoors & Adventure'},
#   'name': 'Austin Sierra Club Outings',
#   'next_event': {'id': '243754992',
#                  'name': 'Thanksgiving Big Bend Trip – Chisos Campground',
#                  'time': 1511355600000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 14},
#   'organizer': {'bio': '',
#                 'id': 10029925,
#                 'name': 'Jack Graham',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/2/8/0/0/highres_7210240.jpeg',
#                           'id': 7210240,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/2/8/0/0/member_7210240.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/2/8/0/0/thumb_7210240.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'Austin-Sierra-Club-Outings',
#   'visibility': 'public',
#   'who': 'Members'},
#  {'category': {'id': 34,
#                'name': 'Tech',
#                'shortname': 'tech',
#                'sort_name': 'Tech'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1440543873000,
#   'description': '<p><b>Welcome to Agile Austin!</b> <br> <br><b>Keeping '
#                  'Austin Agile, One User Story at a Time.</b> <br> <br>Agile '
#                  'Austin is the largest group of Agile professionals in the '
#                  'central Texas Area. As a 501c(6) non-profit (special thanks '
#                  'to&nbsp;<a href="http://www.andrewskurth.com/">Andrews Kurth '
#                  'LLP</a>), we provide and promote gatherings of like-minded '
#                  'individuals in the Austin Area. <br> <br>Agile Austin’s '
#                  'mission is to promote agile software development concepts '
#                  'such as those set forth in the Agile Manifesto (<a '
#                  'href="http://agilemanifesto.org/">agilemanifesto.org</a>), '
#                  'to create a public forum for the exchange of practice '
#                  'information, and to create opportunities for the '
#                  'professional development of members. <br> <br>Come join us, '
#                  "share your ideas and learn from others, and don't forget to "
#                  'check us out at our upcoming conference&nbsp;<a '
#                  'href="https://www.eventbrite.com/e/keep-austin-agile-2016-registration-19091433993?aff=ebrowse">Keep '
#                  'Austin Agile</a>! <br> <br></p>\n'
#                  '<p><img '
#                  'src="https://a248.e.akamai.net/secure.meetupstatic.com/photos/event/9/9/b/3/600_444279347.jpeg"></p>',
#   'id': 18868628,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/a/5/b/8/highres_466242424.jpeg',
#                 'id': 466242424,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/a/5/b/8/600_466242424.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/a/5/b/8/thumb_466242424.jpeg',
#                 'type': 'event'},
#   'lat': 30.27,
#   'link': 'https://www.meetup.com/AgileAustin/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.74,
#   'members': 2416,
#   'meta_category': {'category_ids': [34],
#                     'id': 292,
#                     'name': 'Tech',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/highres_450131949.jpeg',
#                               'id': 450131949,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/600_450131949.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/thumb_450131949.jpeg',
#                               'type': 'event'},
#                     'shortname': 'tech',
#                     'sort_name': 'Tech'},
#   'name': 'Agile Austin',
#   'next_event': {'id': '244054685',
#                  'name': 'Agile Leaders SIG - Perceptions vs. Reality: Tips to '
#                          'Stay Objective',
#                  'time': 1512151200000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 72},
#   'organizer': {'bio': '',
#                 'id': 26699752,
#                 'name': 'Agile Austin',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/4/f/c/5/highres_249140421.jpeg',
#                           'id': 249140421,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/4/f/c/5/member_249140421.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/f/c/5/thumb_249140421.jpeg',
#                           'type': 'member'}},
#   'pro_network': {'name': 'Agile Alliance Community',
#                   'network_url': 'https://www.meetup.com/pro/agilealliance/',
#                   'number_of_groups': 42,
#                   'urlname': 'agilealliance'},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'AgileAustin',
#   'visibility': 'public',
#   'who': 'Agilists'},
#  {'category': {'id': 34,
#                'name': 'Tech',
#                'shortname': 'tech',
#                'sort_name': 'Tech'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1507277804000,
#   'description': '<p>Blockchain Alliance || Austin focuses on Austin based '
#                  'startups, tech news and advice in Austin, a quickly evolving '
#                  'global digital center. Your one source for everything '
#                  'blockchain technology: news, startup information, '
#                  'entrepreneurship and advice in the tech industry in '
#                  'Austin.&nbsp;Join the Blockchain &amp; Ethereum community '
#                  'dedicating their talent and work to transforming our world. '
#                  "The blockchain's ability to adapt, flow and transform.</p>\n"
#                  '<p><i>Come and discover the innovators, leaders, and '
#                  'philosophers in the space showcasing their solutions and '
#                  'meet the technologists who can support your needs.</i></p>\n'
#                  '<p><b>Goal:&nbsp;</b>Monthly Meetup group focused on '
#                  'leveraging blockchain technology, bringing news and tech. We '
#                  'aim to bring together interested parties, developers, and '
#                  'thought leaders in the space.&nbsp;</p>\n'
#                  '<p><b>Participants:</b> Participants will range from people '
#                  'directly involved in the blockchain and people interested in '
#                  'emerging technologies, potential humanitarian/political '
#                  'ventures, and socially conscious citizens of the world. '
#                  'Developers, tech entrepreneurs, social entrepreneurs, '
#                  'philanthropists, impact investors.</p>\n'
#                  '<p><b>Speakers: </b>Each event will include multiple '
#                  'speakers from various backgrounds. Speakers may be '
#                  'developers creating fintech spaces, blockchain dapps, or '
#                  'solutions, consultants, institutions, charities using '
#                  'blockchain solutions, humanitarian workers interested in '
#                  'exploring blockchain tech, and thought leaders in both '
#                  'spaces. Bitcoin, ethereum and other blockchain '
#                  'applications.&nbsp;</p>\n'
#                  '<p>We are a blockchain news meetup that focuses on Austin '
#                  'based startups bringing you the latest in current news. Join '
#                  'fastest growing blockchain network in Austin, see you at our '
#                  'event!&nbsp;You can always find us at&nbsp;<b><a '
#                  'href="http://www.blockchainatx.com/">www.BlockchainAtx.com</a>&nbsp;</b>Bookmark '
#                  'this page or go to our domain for latest blockchain tech '
#                  'news and developments.</p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/8/5/8/d/highres_465214189.jpeg',
#                   'id': 465214189,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/8/5/8/d/600_465214189.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/8/5/8/d/thumb_465214189.jpeg',
#                   'type': 'event'},
#   'id': 26171447,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/9/1/5/4/highres_465217204.jpeg',
#                 'id': 465217204,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/9/1/5/4/600_465217204.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/9/1/5/4/thumb_465217204.jpeg',
#                 'type': 'event'},
#   'lat': 30.27,
#   'link': 'https://www.meetup.com/BlockChain-ATX/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.71,
#   'members': 362,
#   'meta_category': {'category_ids': [34],
#                     'id': 292,
#                     'name': 'Tech',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/highres_450131949.jpeg',
#                               'id': 450131949,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/600_450131949.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/thumb_450131949.jpeg',
#                               'type': 'event'},
#                     'shortname': 'tech',
#                     'sort_name': 'Tech'},
#   'name': 'BlockChain Alliance ATX || Speakers Events, Startups &Trends',
#   'organizer': {'bio': 'lifelong learner of cultures & a global networker. My '
#                        'professional background is in enterprise B2B '
#                        'technology & marketing for F100 companies; IBM, Dell, '
#                        'AT&T, HP etc. Now I help blockchain companies with ICO '
#                        'launches, drive brand awareness & events.',
#                 'id': 46130192,
#                 'name': 'Faisal Khan',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/a/6/1/d/highres_260142525.jpeg',
#                           'id': 260142525,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/a/6/1/d/member_260142525.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/6/1/d/thumb_260142525.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'BlockChain-ATX',
#   'visibility': 'public',
#   'who': 'Members'},
#  {'category': {'id': 31,
#                'name': 'Socializing',
#                'shortname': 'socializing',
#                'sort_name': 'Socializing'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1294166416000,
#   'description': '<p>What BEING AWESOME is all about...</p>\n'
#                  "<p>Targeting those mainly in their 20's or 30's, here is a "
#                  'group designed for getting together to enjoy happy '
#                  'hours/events/shows in the Austin area. Events include hikes, '
#                  'picnics, sport games, concerts, happy hour, and whatever '
#                  'else that attracts interest. Meet at bars, parks, '
#                  'baseball/basketball games, rec-leagues, or anywhere that '
#                  'sounds fun. Not just for singles, not just for couples... '
#                  'this is for ANYONE AND EVERYONE who wants to get off the '
#                  'couch.</p>\n'
#                  '<p>\xa0</p>\n'
#                  '<p>Be SOCIAL. Come hang out.</p>\n'
#                  '<p>\xa0</p>\n'
#                  "<p>I'm also looking for people to help organize events so "
#                  'let me know if you are interested...</p>\n'
#                  '<p>COME BE AWESOME!</p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/9/c/9/2/highres_194200082.jpeg',
#                   'id': 194200082,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/9/c/9/2/600_194200082.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/9/c/9/2/thumb_194200082.jpeg',
#                   'type': 'event'},
#   'id': 1758659,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/3/9/2/c/highres_448874636.jpeg',
#                 'id': 448874636,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/3/9/2/c/600_448874636.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/3/9/2/c/thumb_448874636.jpeg',
#                 'type': 'event'},
#   'lat': 30.27,
#   'link': 'https://www.meetup.com/AustinTexas/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.74,
#   'members': 24343,
#   'meta_category': {'category_ids': [31],
#                     'id': 272,
#                     'name': 'Social',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/highres_450131947.jpeg',
#                               'id': 450131947,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/600_450131947.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/thumb_450131947.jpeg',
#                               'type': 'event'},
#                     'shortname': 'social',
#                     'sort_name': 'Social'},
#   'name': "AWESOME AUSTIN! I'm young, social, in Austin! 20's 30's fun.",
#   'next_event': {'id': 'kvscqlywpbjc',
#                  'name': 'Canceled',
#                  'time': 1511179500000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 5},
#   'organizer': {'bio': 'awesome.',
#                 'id': 10016772,
#                 'name': 'Alex',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/7/c/f/highres_247921999.jpeg',
#                           'id': 247921999,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/7/c/f/member_247921999.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/c/f/thumb_247921999.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'AustinTexas',
#   'visibility': 'public',
#   'who': 'awesome people'},
#  {'category': {'id': 29,
#                'name': 'Sci-Fi & Fantasy',
#                'shortname': 'sci-fi-fantasy',
#                'sort_name': 'Sci-Fi & Fantasy'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1334153709000,
#   'description': '<p>We are the Geeks. We are Whovians, Browncoats, Techies, '
#                  'Trekkies (Classic and NextGen), Jedi Knights,&nbsp;LARPers, '
#                  'board gamers, video gamers, B5ers, comic book fans (both DC '
#                  'and Marvel), and more. We come in every shape and size, and '
#                  'with countless geekish passions.</p>\n'
#                  '<p>But we also&nbsp;share much in common. We think '
#                  'differently.&nbsp;We share imagination. We share visions of '
#                  'brighter futures and worlds of adventure. We share a passion '
#                  'for figuring out new strategies and trying out new '
#                  'solutions. We share a love of space cowboys, starship '
#                  'captains, humble hobbits, time travelers, masked vigilantes, '
#                  'and vampire slayers. We want to boldly go where no one has '
#                  'gone before.</p>\n'
#                  '<p>Most of the time, when we try to share those loves with '
#                  'co-workers and classmates, we only get befuddled looks and '
#                  'rolled eyes in return. But not here. Not now. Here is where '
#                  'you belong - as part of a community of geeks and gamers, '
#                  'sharing our passions with new friends who get it.</p>\n'
#                  '<p>The mission of this group is to build a '
#                  'community&nbsp;where&nbsp;like-minded, fun-loving '
#                  'scifi/fantasy geeks come together and make friends in '
#                  'comfortable environments. We want to open things up for '
#                  'meaningful discussions, fellowship, game challenges, '
#                  'movie/tv series viewing, and more fun events. We also have a '
#                  'Facebook group to complement our face-to-face get-togethers. '
#                  'Please visit us there at <a '
#                  'href="https://www.facebook.com/groups/AustinGeeksAndGamers/">https://www.facebook.com/groups/AustinGeeksAndGamers/</a></p>\n'
#                  '<p>So, no matter what kind of geek you are, you belong here. '
#                  'Speak friend and enter. Welcome!</p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/4/9/a/9/highres_462078857.jpeg',
#                   'id': 462078857,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/4/9/a/9/600_462078857.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/4/9/a/9/thumb_462078857.jpeg',
#                   'type': 'event'},
#   'id': 3648022,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/4/9/d/8/highres_462078904.jpeg',
#                 'id': 462078904,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/4/9/d/8/600_462078904.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/4/9/d/8/thumb_462078904.jpeg',
#                 'type': 'event'},
#   'lat': 30.27,
#   'link': 'https://www.meetup.com/AustinGeeksandGamers/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.74,
#   'members': 4744,
#   'meta_category': {'category_ids': [11, 29],
#                     'id': 182,
#                     'name': 'Sci-Fi & Games',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/2/highres_450131938.jpeg',
#                               'id': 450131938,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/2/600_450131938.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/2/thumb_450131938.jpeg',
#                               'type': 'event'},
#                     'shortname': 'games-sci-fi',
#                     'sort_name': 'Sci-Fi & Games'},
#   'name': 'Austin Geeks and Gamers',
#   'next_event': {'id': 'zjncbpywpbgc',
#                  'name': 'Mothership Board Game Night: Open Board Gaming',
#                  'time': 1511569800000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 15},
#   'organizer': {'bio': '',
#                 'id': 9483031,
#                 'name': 'Johann',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'id': 177501612,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/5/4/6/c/member_177501612.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/5/4/6/c/thumb_177501612.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'AustinGeeksandGamers',
#   'visibility': 'public',
#   'who': 'Geeks and Gamers'},
#  {'category': {'id': 34,
#                'name': 'Tech',
#                'shortname': 'tech',
#                'sort_name': 'Tech'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1466004411000,
#   'description': '<p>Welcome to the official Deep Learning meetup in Austin, '
#                  'Texas. Deep learning offers exciting solutions to an array '
#                  'of computer vision, natural language processing, and other '
#                  'data science problems, made possible by faster computing, '
#                  'richer data sets, and open source frameworks. <br><span> '
#                  '<br>We invite talks from machine learners and data '
#                  'scientists applying deep learning to solve problems along '
#                  'with tutorials and lessons learned. Talks are open to all '
#                  'Deep Learning frameworks (e.g., TensorFlow, Keras, PyTorch, '
#                  'etc.) Please, no sales pitches.&nbsp;</span></p>\n'
#                  '<p><span>If you would like to sponsor our meetup or give a '
#                  'talk, please let us know.</span></p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/c/b/a/9/highres_452632137.jpeg',
#                   'id': 452632137,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/c/b/a/9/600_452632137.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/c/b/a/9/thumb_452632137.jpeg',
#                   'type': 'event'},
#   'id': 20076933,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/c/f/9/f/highres_465653151.jpeg',
#                 'id': 465653151,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/c/f/9/f/600_465653151.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/c/f/9/f/thumb_465653151.jpeg',
#                 'type': 'event'},
#   'lat': 30.27,
#   'link': 'https://www.meetup.com/Austin-Deep-Learning/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.74,
#   'members': 875,
#   'meta_category': {'category_ids': [34],
#                     'id': 292,
#                     'name': 'Tech',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/highres_450131949.jpeg',
#                               'id': 450131949,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/600_450131949.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/thumb_450131949.jpeg',
#                               'type': 'event'},
#                     'shortname': 'tech',
#                     'sort_name': 'Tech'},
#   'name': 'Austin Deep Learning',
#   'next_event': {'id': '244522661',
#                  'name': 'Introduction to Recurrent Neural Networks with '
#                          'Applications to NLP',
#                  'time': 1513125000000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 117},
#   'organizer': {'bio': '',
#                 'id': 16435621,
#                 'name': 'John Ramey',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/7/6/d/4/highres_247470420.jpeg',
#                           'id': 247470420,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/7/6/d/4/member_247470420.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/6/d/4/thumb_247470420.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'Austin-Deep-Learning',
#   'visibility': 'public',
#   'who': 'Machine Learners'},
#  {'category': {'id': 31,
#                'name': 'Socializing',
#                'shortname': 'socializing',
#                'sort_name': 'Socializing'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1481829618000,
#   'description': '<p>This group is for anyone who is looking to make new '
#                  'friends. Whether you are new to Austin, introverted, or just '
#                  'want some new people to hang out with, this group is for '
#                  'you.</p>\n'
#                  '<p>This is a new group, so this is a perfect time to join. '
#                  'We are going to be doing as many meetups as we can to '
#                  'explore everything Austin has to offer. We have members all '
#                  'over Austin, so we will have Meetups in various locations. '
#                  'Everyone is welcome!</p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/8/1/7/highres_458102071.jpeg',
#                   'id': 458102071,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/8/1/7/600_458102071.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/8/1/7/thumb_458102071.jpeg',
#                   'type': 'event'},
#   'id': 21590254,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/8/1/7/highres_458102071.jpeg',
#                 'id': 458102071,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/8/1/7/600_458102071.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/8/1/7/thumb_458102071.jpeg',
#                 'type': 'event'},
#   'lat': 30.22,
#   'link': 'https://www.meetup.com/I-love-Austin-but-I-need-some-f-g-friends/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.75,
#   'members': 4587,
#   'meta_category': {'category_ids': [31],
#                     'id': 272,
#                     'name': 'Social',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/highres_450131947.jpeg',
#                               'id': 450131947,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/600_450131947.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/thumb_450131947.jpeg',
#                               'type': 'event'},
#                     'shortname': 'social',
#                     'sort_name': 'Social'},
#   'name': 'I love Austin, but I need some f*****g friends!',
#   'next_event': {'id': '245325714',
#                  'name': 'Moontower Saloon Music & Drinks 11/30-Dog Friendly',
#                  'time': 1512091800000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 10},
#   'organizer': {'bio': '',
#                 'id': 122443972,
#                 'name': 'Brian',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/d/0/6/d/highres_269753357.jpeg',
#                           'id': 269753357,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/d/0/6/d/member_269753357.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/0/6/d/thumb_269753357.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'I-love-Austin-but-I-need-some-f-g-friends',
#   'visibility': 'public',
#   'who': 'friends'},
#  {'category': {'id': 34,
#                'name': 'Tech',
#                'shortname': 'tech',
#                'sort_name': 'Tech'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1281021012000,
#   'description': '<p>Regardless of your specific background or current '
#                  'technical stack, anyone who wants to be a well-rounded web '
#                  'app developer and keep a finger on the pulse of modern '
#                  'development will love this group.</p>\n'
#                  '<p>Our format will have several areas of focus, which go '
#                  'beyond the typical single-framework/language meetup:</p>\n'
#                  '<p><strong>News From the Bleeding Edge</strong></p>\n'
#                  '<p>Things are changing and new things are emerging in web '
#                  "tech at such a rapid pace that it's almost impossible to "
#                  "keep up. We'll begin each meetup with a recap of the most "
#                  'interesting news each month related to JavaScript tools and '
#                  'frameworks, browsers, HTML5, mobile, web architecture and '
#                  'anything else that modern web developers would want to know '
#                  "about. You won't want to miss this!</p>\n"
#                  '<p><strong>Topic of the Month</strong></p>\n'
#                  '<p>We want each meetup to focus on one or two specific areas '
#                  'of web technology and dive into them deeply enough to be '
#                  'really informative. &nbsp;There are so many tools, libraries '
#                  'and frameworks out there that no one has time to evaluate '
#                  'everything. Just a few examples of things we might dive '
#                  'into, in no particular order: RequireJS, Bower, Jasmine, '
#                  'Backbone, CoffeeScript, HAML, SASS/LESS, jQuery, Angular, '
#                  "etc. &nbsp;Basically, you don't have time to attend every "
#                  "topic-specific meetup in the world, so we'll bring the most "
#                  'interesting topics to our meetup!</p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/c/d/f/2/highres_269272722.jpeg',
#                   'id': 269272722,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/c/d/f/2/600_269272722.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/c/d/f/2/thumb_269272722.jpeg',
#                   'type': 'event'},
#   'id': 1686269,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/8/7/8/7/highres_453454695.jpeg',
#                 'id': 453454695,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/8/7/8/7/600_453454695.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/8/7/8/7/thumb_453454695.jpeg',
#                 'type': 'event'},
#   'lat': 30.27,
#   'link': 'https://www.meetup.com/bleeding-edge-web/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.74,
#   'members': 3039,
#   'meta_category': {'category_ids': [34],
#                     'id': 292,
#                     'name': 'Tech',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/highres_450131949.jpeg',
#                               'id': 450131949,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/600_450131949.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/thumb_450131949.jpeg',
#                               'type': 'event'},
#                     'shortname': 'tech',
#                     'sort_name': 'Tech'},
#   'name': 'Bleeding Edge Web',
#   'organizer': {'bio': '',
#                 'id': 12576861,
#                 'name': 'Brian Moeskau',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/8/c/e/8/highres_34896072.jpeg',
#                           'id': 34896072,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/8/c/e/8/member_34896072.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/c/e/8/thumb_34896072.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'bleeding-edge-web',
#   'visibility': 'public',
#   'who': 'Edgers'},
#  {'category': {'id': 34,
#                'name': 'Tech',
#                'shortname': 'tech',
#                'sort_name': 'Tech'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1435097738000,
#   'description': '<p>Data Scientists in Austin are doing incredible data '
#                  'science: making graph models of symptoms and human disease, '
#                  'extracting insight from huge amounts of data in real time, '
#                  'and building tools to make this whole process easier. We '
#                  'founded this Meetup as a forum to showcase that work.</p>\n'
#                  '<p>This Meetup is organized by Galvanize. Galvanize offers a '
#                  'data science training programs (a 3 month data science '
#                  'immersive and a year long Masters in Data Sciences '
#                  'accredited through the University of New Haven). Learn more '
#                  'at: <a '
#                  'href="http://www.galvanize.com/courses/data-science/www.galvanize.com" '
#                  'class="linkified">http://www.galvanize.com/courses/data-science/www.galvani...</a></p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/b/0/c/a/highres_450105258.jpeg',
#                   'id': 450105258,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/b/0/c/a/600_450105258.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/b/0/c/a/thumb_450105258.jpeg',
#                   'type': 'event'},
#   'id': 18694285,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/8/c/8/c/highres_449435980.jpeg',
#                 'id': 449435980,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/8/c/8/c/600_449435980.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/8/c/8/c/thumb_449435980.jpeg',
#                 'type': 'event'},
#   'lat': 30.22,
#   'link': 'https://www.meetup.com/Austin-Data-Science/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.75,
#   'members': 2659,
#   'meta_category': {'category_ids': [34],
#                     'id': 292,
#                     'name': 'Tech',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/highres_450131949.jpeg',
#                               'id': 450131949,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/600_450131949.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/thumb_450131949.jpeg',
#                               'type': 'event'},
#                     'shortname': 'tech',
#                     'sort_name': 'Tech'},
#   'name': 'Austin Data Science',
#   'next_event': {'id': '244660326',
#                  'name': 'Hack Austin: Presented by the City of Austin + '
#                          'Galvanize',
#                  'time': 1512777600000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 33},
#   'organizer': {'bio': '', 'id': 229237697, 'name': 'Michael Seiler'},
#   'pro_network': {'name': 'Learn Data Science',
#                   'network_url': 'https://www.meetup.com/pro/learn-data-science/',
#                   'number_of_groups': 10,
#                   'urlname': 'learn-data-science'},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'Austin-Data-Science',
#   'visibility': 'public',
#   'who': 'Data Scientists'},
#  {'category': {'id': 12,
#                'name': 'LGBT',
#                'shortname': 'lgbt',
#                'sort_name': 'LGBT'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1240583127000,
#   'description': '<p>The group is for women, including transgendered '
#                  'women,&nbsp;who identify as lesbians.&nbsp; It is a place to '
#                  'connect&nbsp;socially. This group is not a "dating" site so '
#                  'please respect the boundaries of members.&nbsp; Because this '
#                  'group is intended to serve the needs of lesbian women, no '
#                  'men or straight women are allowed at any of our '
# ...
#                        'TX NMLS-917247 | Company TX NMLS-6274\n'
#                        'Equal Housing Lender',
#                 'id': 9902734,
#                 'name': 'Brandon Burkhardt ',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'id': 41083512,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/a/9/f/8/member_41083512.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/9/f/8/thumb_41083512.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'ATXPhotography101',
#   'visibility': 'public',
#   'who': 'Photographers'},
#  {'category': {'id': 16,
#                'name': 'Language & Ethnic Identity',
#                'shortname': 'language',
#                'sort_name': 'Language & Ethnic Identity'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1413824004000,
#   'description': '<p>This group is for anyone looking to enjoy the French '
#                  'language in a friendly group setting.</p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/4/b/2/0/highres_423799232.jpeg',
#                   'id': 423799232,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/4/b/2/0/600_423799232.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/4/b/2/0/thumb_423799232.jpeg',
#                   'type': 'event'},
#   'id': 17747032,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/d/a/c/9/highres_458036009.jpeg',
#                 'id': 458036009,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/d/a/c/9/600_458036009.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/d/a/c/9/thumb_458036009.jpeg',
#                 'type': 'event'},
#   'lat': 30.31,
#   'link': 'https://www.meetup.com/Austin-French-circle-Meetup/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.72,
#   'members': 1017,
#   'meta_category': {'category_ids': [16],
#                     'id': 212,
#                     'name': 'Language & Culture',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/3/highres_450131939.jpeg',
#                               'id': 450131939,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/3/600_450131939.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/3/thumb_450131939.jpeg',
#                               'type': 'event'},
#                     'shortname': 'language',
#                     'sort_name': 'Language & Culture'},
#   'name': 'Austin French Circle',
#   'next_event': {'id': 'smmqwnywpblc',
#                  'name': 'French Drama Club for Adults',
#                  'time': 1511915400000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 2},
#   'organizer': {'bio': 'I am the primary organizer of the Austin French '
#                        'Circle. I love speaking French. I also have working '
#                        'proficiency in Spanish and Arabic. In addition to '
#                        'languages I enjoy business, finance, geopolitics, '
#                        'sports, and film.',
#                 'id': 26589492,
#                 'name': 'Travis',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/5/e/0/highres_261001504.jpeg',
#                           'id': 261001504,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/5/e/0/member_261001504.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/5/e/0/thumb_261001504.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'Austin-French-circle-Meetup',
#   'visibility': 'public_limited',
#   'who': 'French speakers'},
#  {'category': {'id': 31,
#                'name': 'Socializing',
#                'shortname': 'socializing',
#                'sort_name': 'Socializing'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1237407819000,
#   'description': '<p>If you love movies, theater, music or dance. If you want '
#                  'to attend varied local events and meet and dine with '
#                  'like-minded people, this is the group for you. We organize '
#                  'events suitable for adults and singles as well as '
#                  'families.</p>\n'
#                  '<p>How to recognize group members at an event is as easy as '
#                  '1,2,3: <br> <br>1. Show up a little early <br> <br>2. Visit '
#                  '<a '
#                  'href="http://divisionx.com/pal.png">http://divisionx.com/pal.png</a> '
#                  'on your phone <br> <br>3. Make the PAL symbol visible to '
#                  'others so you can recognize members and connect up. <br></p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/2/6/6/6/highres_438189830.jpeg',
#                   'id': 438189830,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/2/6/6/6/600_438189830.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/6/6/6/thumb_438189830.jpeg',
#                   'type': 'event'},
#   'id': 1411974,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/2/3/d/7/highres_445269175.jpeg',
#                 'id': 445269175,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/2/3/d/7/600_445269175.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/3/d/7/thumb_445269175.jpeg',
#                 'type': 'event'},
#   'lat': 30.29,
#   'link': 'https://www.meetup.com/performing-arts-lovers/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.73,
#   'members': 6778,
#   'meta_category': {'category_ids': [31],
#                     'id': 272,
#                     'name': 'Social',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/highres_450131947.jpeg',
#                               'id': 450131947,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/600_450131947.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/thumb_450131947.jpeg',
#                               'type': 'event'},
#                     'shortname': 'social',
#                     'sort_name': 'Social'},
#   'name': 'Performing Arts Lovers (movies, theater, music, dance)',
#   'organizer': {'bio': '',
#                 'id': 34960132,
#                 'name': 'Ata Etemadi',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/6/d/6/c/highres_72028012.jpeg',
#                           'id': 72028012,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/6/d/6/c/member_72028012.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/6/d/6/c/thumb_72028012.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'performing-arts-lovers',
#   'visibility': 'public',
#   'who': 'PALs'},
#  {'category': {'id': 28,
#                'name': 'Religion & Beliefs',
#                'shortname': 'religion-beliefs',
#                'sort_name': 'Religion & Beliefs'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1475724999000,
#   'description': '<p>We are a community of compassion and reason, celebrating '
#                  'the human experience. Oasis is a place for the non religious '
#                  'to come together to celebrate the human experience. Our core '
#                  'values define our community and help shape our interactions '
#                  'with each other, society, and the world:&nbsp;</p>\n'
#                  '<p>People are more important than beliefs <br>Reality is '
#                  'known through reason Meaning comes from making a difference '
#                  '<br>Human hands solve human problems <br>Be accepting and be '
#                  'accepted</p>\n'
#                  '<p>For more information, visit our website at&nbsp;<a '
#                  'href="http://austinoasis.org/">http://austinoasis.org/</a> '
#                  'for more information.&nbsp;</p>\n'
#                  '<p> <br></p>',
#   'id': 20620663,
#   'join_mode': 'open',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/b/5/7/f/highres_458746463.jpeg',
#                 'id': 458746463,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/b/5/7/f/600_458746463.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/b/5/7/f/thumb_458746463.jpeg',
#                 'type': 'event'},
#   'lat': 30.29,
#   'link': 'https://www.meetup.com/Austin-Oasis/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.73,
#   'members': 303,
#   'meta_category': {'category_ids': [22, 24, 28],
#                     'id': 132,
#                     'name': 'Beliefs',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/5/highres_450131925.jpeg',
#                               'id': 450131925,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/5/600_450131925.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/5/thumb_450131925.jpeg',
#                               'type': 'event'},
#                     'shortname': 'beliefs',
#                     'sort_name': 'Beliefs'},
#   'name': 'Austin Oasis: A Humanist Community of Compassion and Reason',
#   'next_event': {'id': 'clzhznywqbfb',
#                  'name': 'Sunday Gathering: A Humanist Community of Compassion '
#                          'and Reason',
#                  'time': 1512320400000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 3},
#   'organizer': {'bio': '',
#                 'id': 220497915,
#                 'name': 'Austin Oasis',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'highres_link': 'https://secure.meetupstatic.com/photos/member/7/2/c/d/highres_263609389.jpeg',
#                           'id': 263609389,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/7/2/c/d/member_263609389.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/2/c/d/thumb_263609389.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'Austin-Oasis',
#   'visibility': 'public',
#   'who': 'Freethinkers'},
#  {'category': {'id': 23,
#                'name': 'Outdoors & Adventure',
#                'shortname': 'outdoors-adventure',
#                'sort_name': 'Outdoors & Adventure'},
#   'city': 'Austin',
#   'country': 'US',
#   'created': 1380238694000,
#   'description': '<p>This is a group for people in the greater Austin area who '
#                  "have RV's and want to&nbsp;meet other like minded folks who "
#                  'like to camp as a group.&nbsp;&nbsp;We tend to prefer state '
#                  'parks because it is affordable for most, but we also camp at '
#                  'other parks.&nbsp; <br></p>\n'
#                  "<p>Although we have mainly&nbsp;RV's, A-frames, and pop ups, "
#                  'tent campers are welcomed, but will be expected to make '
#                  'their own reservations or find someone to share a site '
#                  'with.</p>\n'
#                  '<p>Everyone is welcome, with or without children '
#                  "and/or&nbsp;pets. We tend to be 40's, 50's, 60's, and "
#                  'beyond, mainly with grown kids, but all are welcomed.</p>\n'
#                  '<p>Many of the sites we travel to also have cabins and such, '
#                  'so feel free to join up and come out to enjoy Central Texas '
#                  'with us.</p>',
#   'group_photo': {'base_url': 'https://secure.meetupstatic.com',
#                   'highres_link': 'https://secure.meetupstatic.com/photos/event/7/5/1/1/highres_458369969.jpeg',
#                   'id': 458369969,
#                   'photo_link': 'https://secure.meetupstatic.com/photos/event/7/5/1/1/600_458369969.jpeg',
#                   'thumb_link': 'https://secure.meetupstatic.com/photos/event/7/5/1/1/thumb_458369969.jpeg',
#                   'type': 'event'},
#   'id': 10445222,
#   'join_mode': 'approval',
#   'key_photo': {'base_url': 'https://secure.meetupstatic.com',
#                 'highres_link': 'https://secure.meetupstatic.com/photos/event/9/6/9/3/highres_456518547.jpeg',
#                 'id': 456518547,
#                 'photo_link': 'https://secure.meetupstatic.com/photos/event/9/6/9/3/600_456518547.jpeg',
#                 'thumb_link': 'https://secure.meetupstatic.com/photos/event/9/6/9/3/thumb_456518547.jpeg',
#                 'type': 'event'},
#   'lat': 30.27,
#   'link': 'https://www.meetup.com/Austin-Area-RVers/',
#   'localized_country_name': 'USA',
#   'localized_location': 'Austin, TX',
#   'lon': -97.74,
#   'members': 79,
#   'meta_category': {'category_ids': [3, 23],
#                     'id': 242,
#                     'name': 'Outdoors & Adventure',
#                     'photo': {'base_url': 'https://secure.meetupstatic.com',
#                               'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/highres_450131943.jpeg',
#                               'id': 450131943,
#                               'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/600_450131943.jpeg',
#                               'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/thumb_450131943.jpeg',
#                               'type': 'event'},
#                     'shortname': 'outdoors-adventure',
#                     'sort_name': 'Outdoors & Adventure'},
#   'name': "Austin RVer's",
#   'next_event': {'id': '239832128',
#                  'name': 'Bastrop SP 2017 Dec 1-3',
#                  'time': 1512151200000,
#                  'utc_offset': -21600000,
#                  'yes_rsvp_count': 37},
#   'organizer': {'bio': '',
#                 'id': 78843312,
#                 'name': 'Linda and Charles',
#                 'photo': {'base_url': 'https://secure.meetupstatic.com',
#                           'id': 98580212,
#                           'photo_link': 'https://secure.meetupstatic.com/photos/member/d/4/member_98580212.jpeg',
#                           'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/4/thumb_98580212.jpeg',
#                           'type': 'member'}},
#   'score': 1.0,
#   'state': 'TX',
#   'status': 'active',
#   'timezone': 'US/Central',
#   'urlname': 'Austin-Area-RVers',
#   'visibility': 'public_limited',
#   'who': "Austin RVer's"}]
